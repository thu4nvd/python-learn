# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.15.1'

# %%
x = np.linspace(-5, 5, 100)
y = np.sin(x)
plt.plot(x, y)
plt.plot(x+1, y)

# %%
A = np.array([1,2,3,4])
type(A)
# Out:
# numpy.ndarray
