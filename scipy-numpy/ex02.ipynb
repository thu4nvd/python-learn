# %%
from numpy import pi
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*pi, 2*pi, 100)
f_sin = np.sin(x)
f_cos = np.cos(x)
f_tan = np.tan(x)
plt.plot(x,f_sin)

# %%
plt.plot(x,f_cos)

# %%
plt.plot(x,f_tan)
